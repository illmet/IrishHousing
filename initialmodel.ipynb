# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("df23.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                         Address County  \
# 0           0  15 ST JOHNS TERRACE, OLD YOUGHAL RD, CORK CITY   Cork
# 1           1                2 KINGS TERRACE, CORK CITY, CORK   Cork
# 2           2                     22 COVE ST, CORK CITY, CORK   Cork
# 3           3                   3 PARK HILL, SKEHARD RD, CORK   Cork
# 4           4              4 SULLIVANS LANE, BARRACK ST, CORK   Cork
#
#                                                 Full        Date  \
# 0  15 ST JOHNS TERRACE, OLD YOUGHAL RD, CORK CITY...  2023-01-01
# 1             2 KINGS TERRACE, CORK CITY, CORK, Cork  2023-01-01
# 2                  22 COVE ST, CORK CITY, CORK, Cork  2023-01-01
# 3                3 PARK HILL, SKEHARD RD, CORK, Cork  2023-01-01
# 4           4 SULLIVANS LANE, BARRACK ST, CORK, Cork  2023-01-01
#
#    Full Market Price  VAT exclusive   Latitude  Longitude     Price
# 0                  1              0  51.911373  -8.442231  160000.0
# 1                  1              0  51.901490  -8.463452  180000.0
# 2                  1              0  51.895019  -8.475927  120000.0
# 3                  1              0  51.886775  -8.427577  320000.0
# 4                  1              0  51.892899  -8.478891   80000.0

# %%
import matplotlib.pyplot as plt

#df.hist(bins=50, figsize=(12, 8))
#plt.show()

# %%
corr_matrix = df[["Latitude", "Longitude", "Price"]].corr()
corr_matrix["Price"].sort_values(ascending=False)
# Out:
# Price        1.000000
# Longitude    0.043083
# Latitude     0.007528
# Name: Price, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = ["Latitude", "Longitude"]
scatter_matrix(df[attributes], figsize=(12, 8))
plt.show()

# %%
df["Price"].memory_usage(deep=True)
# Out:
# 215120

# %%
plt.hist(df["Price"])  # density=False would make counts
# Out:
# (array([2.6864e+04, 8.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([5.00100000e+03, 2.25045009e+07, 4.50040008e+07, 6.75035007e+07,
#         9.00030006e+07, 1.12502500e+08, 1.35002000e+08, 1.57501500e+08,
#         1.80001000e+08, 2.02500500e+08, 2.25000000e+08]),
#  <BarContainer object of 10 artists>)
